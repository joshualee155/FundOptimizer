# %%
import pandas as pd

# %%
df = pd.read_csv('backtest.csv', index_col=0, parse_dates=True)

# %%
df.plot(legend=False)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.sum(axis=1).plot()
# Out:
# <AxesSubplot:xlabel='date'>
