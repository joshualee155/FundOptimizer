# %%
import pandas as pd

# %%
target_rets = [0.01, 0.02, 0.04]

# %%
dfs = [pd.read_csv(f'backtest_2020-01-29_2021-05-21_120_20_{target_ret}.csv', index_col=0, parse_dates=True) for target_ret in target_rets]

# %%
for df in dfs:
    df.fillna(0.0).plot(legend=False)

# %%
for df in dfs:
    df.sum(axis=1).plot()

# %%
df.columns
# Out:
# Index(['000239', '000727', '001717', '001213', '164403', '001300', '002224',
#        '003634', '162108', '510630', '000991', '001148', '002190', '000970',
#        '001635', '001724', '003426', '001951', '002862', '160620', '001866',
#        '002681', '166019', '501025', '502023', '001487', '001718', '002149'],
#       dtype='object')
