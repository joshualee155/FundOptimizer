# %% [markdown]
# # Factor model applied to Chinese stock market

# %%
from arctic import Arctic
# Out:
# c:\users\josh\source\repos\arctic\arctic\store\_pandas_ndarray_store.py:6: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import DataFrame, Series, Panel

# %%
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression

# %%
a = Arctic('localhost')

# %%
lib_stock = a['stock']
lib_basic = a['stock_basics']
lib_index = a['index']

# %%
def get_sw_industry_class():
    """
    Returns Shen-Wan indsutry classification table
    """
    industry = pd.read_html('./refData/SwClass.xls', encoding='GBK')[0]
    IND_RENAME = {
        '行业名称':'industry', 
        '股票代码':'symbol', 
        '股票名称':'name', 
        '起始日期':'start_date', 
        '结束日期':'end_date',
    }

    industry = industry.rename(columns=IND_RENAME)
    industry['symbol'] = industry.symbol.astype(str).str.zfill(6)
    
    return industry

# %%
industry = get_sw_industry_class()

# %%
symbol_2_ind=industry.set_index('symbol')['industry'].to_dict()

# %%
ind_2_index = {
 '农林牧渔': '801010',
 '采掘': '801020',
 '化工': '801030',
 '钢铁': '801040',
 '有色金属': '801050',
 '建筑建材': '801060',
 '机械设备': '801890',
 '电子': '801080',
 '交运设备': '801090',
 '信息设备': '801100',
 '家用电器': '801110',
 '食品饮料': '801120',
 '纺织服装': '801130',
 '轻工制造': '801140',
 '医药生物': '801150',
 '公用事业': '801160',
 '交通运输': '801170',
 '房地产': '801180',
 '金融服务': '801190',
 '商业贸易': '801200',
 '休闲服务': '801210',
 '信息服务': '801220',
 '综合': '801230',
 '建筑材料': '801710',
 '建筑装饰': '801720',
 '电气设备': '801730',
 '国防军工': '801740',
 '计算机': '801750',
 '传媒': '801760',
 '通信': '801770',
 '银行': '801780',
 '非银金融': '801790',
 '汽车': '801880',
}

# %%
est_window = pd.bdate_range('2018-10-23', '2020-10-23')

# %%
all_stocks = lib_stock.list_symbols()

# %%
from tqdm import tqdm

# %%
beta = {}
residual = pd.DataFrame(index = est_window)

# %%
df_index_full = lib_index.read(list(ind_2_index.values()), chunk_range=est_window)

# %%
for ts_code in tqdm(all_stocks):
    stock = ts_code.split('.')[0]
    if stock in symbol_2_ind:
        ind = symbol_2_ind[stock]
        sw_symbol = ind_2_index[ind]
        
        df_stock = lib_stock.read(ts_code, chunk_range=est_window)
        df_index = df_index_full[sw_symbol]
        
        if len(df_stock) < 0.6 * len(df_index):
            continue
        
        # Extract pct_chg from index and stock
        y = df_stock['pct_chg']/100.
        X = df_index[['pct_chg']].reindex(y.index)/100.
       
        lr = LinearRegression(fit_intercept=False)
        lr.fit(X, y)
        beta[stock]=lr.coef_[0]
        y_hat = lr.predict(X)
        residual[stock] = y-y_hat
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4040/4040 [05:22<00:00, 12.53it/s]

# %%
len(beta)
# Out:
# 3629

# %%
y.tail(20)
# Out:
# date
# 2020-09-18   -0.011686
# 2020-09-21   -0.028882
# 2020-09-22   -0.040519
# 2020-09-23    0.032453
# 2020-09-24   -0.014910
# 2020-09-25    0.010841
# 2020-09-28   -0.042898
# 2020-09-29    0.031078
# 2020-09-30    0.009842
# 2020-10-09    0.049746
# 2020-10-12    0.063830
# 2020-10-13    0.002182
# 2020-10-14   -0.006531
# 2020-10-15   -0.006939
# 2020-10-16   -0.011769
# 2020-10-19   -0.000744
# 2020-10-20    0.005773
# 2020-10-21    0.029439
# 2020-10-22    0.026439
# 2020-10-23   -0.018749
# Name: pct_chg, dtype: float64

# %%
df = pd.concat( list(df_index_full.values()) )

# %%
returns = df.reset_index().pivot_table('pct_chg', 'date', 'name')/100.

# %%
returns.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col1 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col2 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col3 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col4 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col5 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col6 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col7 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col8 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col9 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col10 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col11 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col12 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col13 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col14 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col15 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col16 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col17 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col18 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col19 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col20 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col21 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col22 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col23 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col24 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col25 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col26 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row0_col27 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col0 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col2 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col3 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col4 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col5 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col6 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col7 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col8 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col9 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col10 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col11 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col12 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col13 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col14 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col15 {
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col16 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col17 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col18 {
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col19 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col20 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col21 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col22 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col23 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col24 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col25 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col26 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row1_col27 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row2_col0 {
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row2_col1 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f477952c_1b81_11eb_974d_9cb6d0eebed8row2_col3 {
#             background-color:  #8bb2

# %%
close_prices = df.reset_index().pivot_table('close', 'date', 'symbol')

# %%
rolling = returns.rolling(250).corr().unstack(level=1).dropna()

# %%
import matplotlib
matplotlib.rc('font', family='MicroSoft YaHei')
